# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #graph
# #plot
# #scatter
# #hist
# #bar
# #pie

# %%
x = [1,2,3,4]
y = [2,4,6,8]
plt.plot(x,y,'o')               #to plot the graph
plt.show()

# %%
x = [1,2,3,4]
y = [2,4,6,8]
plt.plot(x,y,marker='*')               #to plot the graph
plt.show()

# %%
x = [1,2,3,4]
y = [2,4,6,8]
plt.plot(x,y,'o:r')               #o = circle, : = dotted line, r = red colour
plt.show()

# %%
x = [1,2,3,4]
y = [2,4,6,8]
plt.plot(x,y,'o-r')               #o = circle, : = dotted line, r = red colour
plt.show()

# %%
x = [1,2,3,4]
y = [2,4,6,8]
plt.plot(x,y,ms = 20,marker = 'o',color = 'red')               #ms = marker size
# returns address of plotted graph

# %%
x = [1,2,3,4]
y = [2,4,6,8]
plt.plot(x,y,ms = 20 ,marker= "*")              
plt.show()

# %%
x = [1,2,3,4]
y = [2,4,6,8]
plt.plot(x,y,ms = 20 ,marker= "*",mfc = 'red')               #mfc = change color inside marker
plt.show()

# %%
x = [1,2,3,4]
y = [2,4,6,8]
plt.plot(x,y,ms = 20 ,marker= "*",mfc = 'red',mec = "yellow")               #mec = changes the color of marker's border
plt.show()

# %%
arr =[1,3,5,7]
plt.plot(arr,ls= 'dashed')
plt.show()

# %%
arr =[1,3,5,7]
plt.plot(arr,ls= 'dotted')
plt.show()

# %%
arr =[1,3,5,7]
plt.plot(arr,linewidth = 20)
plt.show()

# %%
x = [1,3,5,7]
y = [4,5,6,7]
plt.plot(x,color = 'red')
plt.plot(y)
plt.show()

# %%
x = [1,3,5,7]
y = [4,5,6,7]
plt.xlabel("oiuytf")
plt.ylabel('yaxis')
plt.title('Matplotlib')
plt.plot(x)
plt.show()

# %%
x = [1,3,5,7]
y = [4,5,6,7]
plt.xlabel("oiuytf")
plt.ylabel('yaxis')
plt.title('Matplotlib')
plt.grid()
plt.plot(x)
plt.show()

# %%
plt.plot([1,2,3,4])

# %%
xpoint = np.array([1,2,3,4])
ypoint = np.array([2,4,6,8])
plt.plot(xpoint,ypoint)
xxpoint = np.array([5,6,7,8])
xypoint = np.array([4,5,6,7])
plt.plot(xxpoint,xypoint)
plt.show()

# %%
xpoint = np.array([1,2,3,4])
ypoint = np.array([2,4,6,8])
plt.scatter(xpoint,ypoint)
plt.show()

# %%
xpoint = np.array([1,2,3,4])
ypoint = np.array([2,4,6,8])
plt.scatter(xpoint,ypoint)
xxpoint = np.array([5,6,7,8])
xypoint = np.array([4,5,6,7])
plt.scatter(xxpoint,xypoint)
plt.show()

# %%
xpoint = np.array([1,2,3,4])
ypoint = np.array([2,4,6,8])
color = np.array(['red','blue','black','cyan'])
plt.scatter(xpoint,ypoint,c = color)
plt.show()

# %%
xpoint = np.array([1,2,3,4])
ypoint = np.array([2,4,6,8])
color = np.array(['red','blue','black','cyan'])
size = np.array([10,20,30,40])
plt.scatter(xpoint,ypoint,c = color,s = size)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y, s = sizes, c = c )
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y, s = sizes, c = c ,alpha=0.5)                  #alpha = visibility
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y, s = sizes, c = c ,alpha=0.5)    
plt.colorbar()              #alpha = visibility
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.bar(x,y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.barh(x,y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.bar(x,y,color = "purple")
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.bar(x,y,color = c)
plt.show()

# %%
x = np.random.normal(170 ,10,250)
x
# Out:
# array([175.7107889 , 149.12366004, 161.15083316, 156.84306389,
#        182.51639847, 171.29320639, 163.15536665, 150.05257818,
#        151.63965895, 157.45211286, 160.42471194, 165.16655929,
#        170.68111397, 175.30122341, 159.09384457, 167.97388954,
#        174.82525548, 176.15495229, 161.96073637, 167.58404484,
#        191.58049858, 166.06275847, 181.76252192, 155.54378878,
#        175.57572129, 160.74765781, 161.86822075, 172.67539171,
#        169.91578668, 165.25633127, 161.03471447, 177.01974349,
#        158.33512206, 158.51862983, 176.00316799, 160.29308559,
#        181.23404862, 171.86141141, 160.24995732, 180.52518221,
#        166.58791005, 179.53904135, 167.1087381 , 171.95004606,
#        185.42610412, 165.06565158, 169.82540714, 172.90419573,
#        160.79796274, 168.76079472, 153.60433499, 161.25532313,
#        182.73083487, 171.55120663, 165.24943731, 180.15361043,
#        169.78019993, 171.9061489 , 161.38720494, 161.72629586,
#        196.81217624, 177.51577402, 168.54902427, 173.35057323,
#        178.58022607, 189.09062548, 186.80903142, 176.61766833,
#        175.74549557, 164.07218773, 163.51217494, 186.15101437,
#        162.28397203, 168.9570539 , 170.66917946, 183.56048327,
#        169.20219126, 161.25226867, 176.8941799 , 181.83358764,
#        186.94303869, 164.6459292 , 161.91361301, 150.30628327,
#        170.04643961, 173.7870972 , 176.36434233, 155.56168732,
#        156.43261619, 175.22390708, 166.84667465, 190.38656107,
#        162.83504325, 170.13866851, 170.18399001, 191.11040622,
#        168.20894383, 154.44916255, 169.43842762, 181.39423485,
#        161.65898484, 156.24685094, 174.7245123 , 163.63108516,
#        181.63786601, 158.12448334, 172.66275775, 165.91203155,
#        172.51067318, 142.83597585, 154.12732292, 161.63875179,
#        182.85901111, 169.68498807, 186.96989441, 173.94960391,
#        167.22591797, 170.96607784, 179.65940625, 156.66393804,
#        171.63355456, 161.48681902, 176.34030801, 167.32007286,
#        152.83316873, 172.02374273, 168.65363781, 164.72464415,
#        167.99849795, 174.84912188, 148.72263737, 180.91142402,
#        157.61106466, 177.13625304, 167.41464756, 169.48376077,
#        166.13662665, 144.68719394, 172.99162249, 162.23105125,
#        165.17173068, 176.69590035, 171.3926717 , 177.26414991,
#        165.57997505, 186.92329956, 156.56388285, 151.95409765,
#        169.19135263, 178.88495713, 155.84225291, 152.05803148,
#        188.05323444, 184.5981602 , 169.98629919, 169.83932688,
#        173.55367661, 177.16137305, 162.07880704, 171.98863676,
#        167.31619065, 173.21745024, 163.60248006, 168.32296836,
#        168.96889444, 177.41247785, 177.56355738, 175.39536577,
#        173.16804256, 158.80875387, 152.60277147, 159.6803508 ,
#        169.29048282, 164.51795222, 173.46461417, 162.5269744 ,
#        153.82827405, 157.69432104, 164.93655296, 172.99232223,
#        170.21515823, 162.23096144, 178.08014878, 145.81629403,
#        171.48770438, 159.56324831, 174.74208185, 161.74930067,
#        168.57844694, 166.75076719, 172.47008076, 169.19227294,
#        174.16332528, 158.05616998, 195.22901202, 154.50147955,
#        174.88633236, 174.87321331, 182.70166861, 157.25822492,
#        162.58318408, 153.36634569, 168.25695224, 151.78795452,
#        175.588082  , 162.14832595, 174.27756299, 178.1111098 ,
#        167.2916459 , 180.82049828, 173.43655261, 160.91380034,
#        176.75149468, 173.26698278, 158.40652085, 155.71897804,
#        173.12924178, 155.14530123, 162.1759235 , 168.2908152 ,
#        180.0650385 , 167.32447445, 174.137234  , 178.70725437,
#        178.34619713, 158.68249032, 172.2675658 , 171.8677193 ,
#        160.30543276, 171.40583078, 198.4152808 , 175.95821897,
#        167.90057194, 153.81639759, 169.15987328, 168.56410897,
#        165.95826251, 173.94497696, 166.94351072, 161.45223562,
#        160.51121062, 173.970407  , 169.48961564, 160.15351124,
#        174.22509768, 166.21090311, 165.39616582, 179.0430531 ,
#        173.3359391 , 164.54700957])

# %%
x = np.random.normal(170,10,250)
plt.hist(x)
plt.show()

# %%
x = np.array([1,3,5,7])
plt.pie(x)
plt.show()

# %%
x = np.array([1,3,5,7])
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x2c1433e3390>,
#   <matplotlib.patches.Wedge at 0x2c1421d5750>,
#   <matplotlib.patches.Wedge at 0x2c1421d5090>,
#   <matplotlib.patches.Wedge at 0x2c1421d59d0>],
#  [Text(1.078863807270999, 0.21459936011257072, ''),
#   Text(0.6111272177057369, 0.9146165993350683, ''),
#   Text(-0.9146166260482878, 0.6111271777265734, ''),
#   Text(0.2145994533595093, -1.078863788723025, '')])

# %%
x = np.array([1,3,5,7])
label = ['apple','mango','banana','anar']
plt.pie(x,labels=label)
plt.show()

# %%
x = np.array([1,3,5,7])
label = ['apple','mango','banana','anar']
plt.pie(x,labels=label,explode = [0,0.2,0,0],shadow = True)
plt.show()

# %%
x = np.array([1,3,5,7])
label = ['apple','mango','banana','anar']
colr = ['blue','pink','green','red']
plt.pie(x,labels=label,explode = [0,0.2,0,0],shadow = True, colors=colr)
plt.show()

# %%
x = np.array([1,3,5,7])
label = ['apple','mango','banana','anar']
plt.pie(x,labels=label,explode = [0,0.2,0,0],shadow = True,autopct='%1.1f%%')
plt.show()

# %%
x = np.array([1,3,5,7])
label = ['apple','mango','banana','anar']
plt.pie(x,labels=label,explode = [0,0.2,0,0],shadow = True,autopct='%1.1f%%')
plt.legend()
plt.show()
