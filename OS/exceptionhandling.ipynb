# %% [markdown]
# ### Exception Handling
# Exception handling in Python is a way to handle errors gracefully so that a program does not crash unexpectedly.
#
# An exception is an error that occurs during program execution.
