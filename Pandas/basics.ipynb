# %% [markdown]
# ### Pandas
# `pandas` is one of the most popular Python libraries for data analysis and manipulation. It provides powerful tools to work with tables, spreadsheets, CSV files, databases, and time-series data.

# %%
import os
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\user\OneDrive\Desktop\Data Science\ML\Projects\BIke prediction\Used_Bikes.csv")          #df = data frame
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.head()       #by default return top 5 rows
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.head(10)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# ...

# %%
df.tail()           #by default returns 5 rows from bottom
# Out:
#                        bike_name    price    city  kms_driven        owner  \
# 32643     Hero Passion Pro 100cc  39000.0   Delhi     22000.0  First Owner
# 32644       TVS Apache RTR 180cc  30000.0  Karnal      6639.0  First Owner
# 32645   Bajaj Avenger Street 220  60000.0   Delhi     20373.0  First Owner
# 32646  Hero Super Splendor 125cc  15600.0  Jaipur     84186.0  First Owner
# 32647         Bajaj Pulsar 150cc  22000.0    Pune     60857.0  First Owner
#
#         age  power  brand
# 32643   4.0  100.0   Hero
# 32644   9.0  180.0    TVS
# 32645   6.0  220.0  Bajaj
# 32646  16.0  125.0   Hero
# 32647  13.0  150.0  Bajaj

# %%
df.tail(10)
# Out:
#                          bike_name     price         city  kms_driven  \
# 32638        Yamaha Fazer 25 250cc  123000.0       Kadapa     14500.0
# 32639  Royal Enfield Classic 350cc   95500.0        Delhi     18000.0
# 32640       Hero Passion Pro 100cc   32000.0        Delhi     12000.0
# 32641          Bajaj Avenger 220cc   41000.0        Delhi     20245.0
# 32642           Hero Passion 100cc   15000.0  Perumbavoor     35000.0
# 32643       Hero Passion Pro 100cc   39000.0        Delhi     22000.0
# 32644         TVS Apache RTR 180cc   30000.0       Karnal      6639.0
# 32645     Bajaj Avenger Street 220   60000.0        Delhi     20373.0
# 32646    Hero Super Splendor 125cc   15600.0       Jaipur     84186.0
# 32647           Bajaj Pulsar 150cc   22000.0         Pune     60857.0
#
#               owner   age  power          brand
# 32638   First Owner   4.0  250.0         Yamaha
# 32639   First Owner   8.0  350.0  Royal Enfield
# 32640   First Owner   6.0  100.0           Hero
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  str
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  str
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  str
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  str
# dtypes: float64(4), str(4)
# memory usage: 2.0 MB

# %%
df.columns
# Out:
# Index(['bike_name', 'price', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='str')

# %%
df["bike_name"]             #return specific column data
# Out:
# 0          TVS Star City Plus Dual Tone 110cc
# 1                 Royal Enfield Classic 350cc
# 2                        Triumph Daytona 675R
# 3                        TVS Apache RTR 180cc
# 4        Yamaha FZ S V 2.0 150cc-Ltd. Edition
#                          ...
# 32643                  Hero Passion Pro 100cc
# 32644                    TVS Apache RTR 180cc
# 32645                Bajaj Avenger Street 220
# 32646               Hero Super Splendor 125cc
# 32647                      Bajaj Pulsar 150cc
# Name: bike_name, Length: 32648, dtype: str

# %%
df[["brand"]]           #return specific column data in data frame
# Out:
#                brand
# 0                TVS
# 1      Royal Enfield
# 2            Triumph
# 3                TVS
# 4             Yamaha
# ...              ...
# 32643           Hero
# 32644            TVS
# 32645          Bajaj
# 32646           Hero
# 32647          Bajaj
#
# [32648 rows x 1 columns]

# %%
df[["age","brand"]]
# Out:
#         age          brand
# 0       3.0            TVS
# 1       4.0  Royal Enfield
# 2       8.0        Triumph
# 3       4.0            TVS
# 4       3.0         Yamaha
# ...     ...            ...
# 32643   4.0           Hero
# 32644   9.0            TVS
# 32645   6.0          Bajaj
# 32646  16.0           Hero
# 32647  13.0          Bajaj
#
# [32648 rows x 2 columns]

# %%
df["brand"].unique()                #returns uniques values
# Out:
# <StringArray>
# [            'TVS',   'Royal Enfield',         'Triumph',          'Yamaha',
#            'Honda',            'Hero',           'Bajaj',          'Suzuki',
#          'Benelli',             'KTM',        'Mahindra',        'Kawasaki',
#           'Ducati',         'Hyosung', 'Harley-Davidson',            'Jawa',
#              'BMW',          'Indian',         'Rajdoot',             'LML',
#            'Yezdi',              'MV',           'Ideal']
# Length: 23, dtype: str

# %%
df["owner"].unique()
# Out:
# <StringArray>
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More']
# Length: 4, dtype: str

# %%
df["age"].unique()
# Out:
# array([ 3.,  4.,  8.,  6.,  7.,  5.,  2., 16., 13.,  9., 10., 14., 12.,
#        11.,  1., 15., 39., 17., 18., 30., 19., 23., 41., 27., 37., 24.,
#        20., 43., 38., 63., 34., 31., 22., 26., 25.])

# %%
df["brand"].nunique()               #returns numbr of unique values
# Out:
# 23

# %%
df["brand"].value_counts()
# Out:
# brand
# Bajaj              11213
# Hero                6368
# Royal Enfield       4178
# Yamaha              3916
# Honda               2108
# Suzuki              1464
# TVS                 1247
# KTM                 1077
# Harley-Davidson      737
# Kawasaki              79
# Hyosung               64
# Benelli               56
# Mahindra              55
# Triumph               26
# Ducati                22
# BMW                   16
# Jawa                  10
# MV                     4
# Indian                 3
# Ideal                  2
# Rajdoot                1
# LML                    1
# Yezdi                  1
# Name: count, dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32643     True
# 32644     True
# 32645     True
# 32646     True
# 32647     True
# Length: 32648, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(25324)

# %%
df.drop_duplicates()
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.drop_duplicates(inplace=True)            #inplace = True permanently makes change in data frame

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df.isna().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df.dropna()         #to remove null values
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
#y = mx + c   
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 7324 entries, 0 to 9372
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   7324 non-null   str
#  1   price       7324 non-null   float64
#  2   city        7324 non-null   str
#  3   kms_driven  7324 non-null   float64
#  4   owner       7324 non-null   str
#  5   age         7324 non-null   float64
#  6   power       7324 non-null   float64
#  7   brand       7324 non-null   str
# dtypes: float64(4), str(4)
# memory usage: 515.0 KB

# %%
df['owner'].unique()
# Out:
# <StringArray>
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More']
# Length: 4, dtype: str

# %%
owner_dict = {
 'First Owner':1, 'Second Owner':2, 'Third Owner':3, 'Fourth Owner Or More':4   
}

# %%
# df['owner']=df['owner'].map(owner_dict)

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 7324 entries, 0 to 9372
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   7324 non-null   str
#  1   price       7324 non-null   float64
#  2   city        7324 non-null   str
#  3   kms_driven  7324 non-null   float64
#  4   owner       7324 non-null   str
#  5   age         7324 non-null   float64
#  6   power       7324 non-null   float64
#  7   brand       7324 non-null   str
# dtypes: float64(4), str(4)
# memory usage: 515.0 KB

# %%
# df.drop('city',axis=1,inplace=True)

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
# df.drop(['age','power'],axis=1)

# %%
df['brand'].unique()
# Out:
# <StringArray>
# [            'TVS',   'Royal Enfield',         'Triumph',          'Yamaha',
#            'Honda',            'Hero',           'Bajaj',          'Suzuki',
#          'Benelli',             'KTM',        'Mahindra',        'Kawasaki',
#           'Ducati',         'Hyosung', 'Harley-Davidson',            'Jawa',
#              'BMW',          'Indian',         'Rajdoot',             'LML',
#            'Yezdi',              'MV',           'Ideal']
# Length: 23, dtype: str

# %%
brand_dict = {
     'TVS':1, 'Royal Enfield':2,         'Triumph':3,          'Yamaha':4,
           'Honda':5,            'Hero':6,           'Bajaj':7,          'Suzuki':8,
         'Benelli':9,             'KTM':10,        'Mahindra':11,        'Kawasaki':12,
          'Ducati':13,         'Hyosung':14, 'Harley-Davidson':15,            'Jawa':16,
             'BMW':17,          'Indian':18,         'Rajdoot':19,             'LML':20,
           'Yezdi':21,              'MV':22,           'Ideal':23
}

# %%
# df['brand']=df['brand'].map(brand_dict)

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 7324 entries, 0 to 9372
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   7324 non-null   str
#  1   price       7324 non-null   float64
#  2   city        7324 non-null   str
#  3   kms_driven  7324 non-null   float64
#  4   owner       7324 non-null   str
#  5   age         7324 non-null   float64
#  6   power       7324 non-null   float64
#  7   brand       7324 non-null   str
# dtypes: float64(4), str(4)
# memory usage: 515.0 KB

# %%
obj_val = df.select_dtypes(include='object')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7828\3590679278.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   obj_val = df.select_dtypes(include='object')

# %%
obj_val
# Out:
#                                  bike_name       city        owner  \
# 0       TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1              Royal Enfield Classic 350cc      Delhi  First Owner
# 2                     Triumph Daytona 675R      Delhi  First Owner
# 3                     TVS Apache RTR 180cc  Bangalore  First Owner
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
# ...                                    ...        ...          ...
# 9362             Hero Hunk Rear Disc 150cc      Delhi  First Owner
# 9369                   Bajaj Avenger 220cc  Bangalore  First Owner
# 9370        Harley-Davidson Street 750 ABS    Jodhpur  First Owner
# 9371                 Bajaj Dominar 400 ABS  Hyderabad  First Owner
# 9372              Bajaj Avenger Street 220  Hyderabad  First Owner
#
#                 brand
# 0                 TVS
# 1       Royal Enfield
# 2             Triumph
# 3                 TVS
# 4              Yamaha
# ...

# %%
num_val = df.select_dtypes(exclude='object')

# %%
num_val
# Out:
#          price  kms_driven  age  power
# 0      35000.0     17654.0  3.0  110.0
# 1     119900.0     11000.0  4.0  350.0
# 2     600000.0       110.0  8.0  675.0
# 3      65000.0     16329.0  4.0  180.0
# 4      80000.0     10000.0  3.0  150.0
# ...        ...         ...  ...    ...
# 9362   25000.0     48587.0  8.0  150.0
# 9369   35000.0     60000.0  9.0  220.0
# 9370  450000.0      3430.0  4.0  750.0
# 9371  139000.0     21300.0  4.0  400.0
# 9372   80000.0      7127.0  5.0  220.0
#
# [7324 rows x 4 columns]

# %%
complete_data = pd.concat([obj_val,num_val],axis=1)

# %%
complete_data
# Out:
#                                  bike_name       city        owner  \
# 0       TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1              Royal Enfield Classic 350cc      Delhi  First Owner
# 2                     Triumph Daytona 675R      Delhi  First Owner
# 3                     TVS Apache RTR 180cc  Bangalore  First Owner
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
# ...                                    ...        ...          ...
# 9362             Hero Hunk Rear Disc 150cc      Delhi  First Owner
# 9369                   Bajaj Avenger 220cc  Bangalore  First Owner
# 9370        Harley-Davidson Street 750 ABS    Jodhpur  First Owner
# 9371                 Bajaj Dominar 400 ABS  Hyderabad  First Owner
# 9372              Bajaj Avenger Street 220  Hyderabad  First Owner
#
#                 brand     price  kms_driven  age  power
# 0                 TVS   35000.0     17654.0  3.0  110.0
# ...

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
tvs_brand = df[df['brand']=='TVS']

# %%
tvs_brand
# Out:
#                                bike_name    price       city  kms_driven  \
# 0     TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 3                   TVS Apache RTR 180cc  65000.0  Bangalore     16329.0
# 52                  TVS Apache RTR 160cc  60000.0     Mumbai     30000.0
# 114           TVS Apache RTR 160 4V Disc  69900.0      Delhi      8700.0
# 130               TVS Phoenix Disc 125cc  21500.0    Barasat     10500.0
# ...                                  ...      ...        ...         ...
# 9247      TVS Apache RTR 160cc Rear Disc  70000.0  Ghaziabad      4116.0
# 9307                TVS Apache RTR 160cc  30000.0     Alibag     30000.0
# 9312            TVS Apache RTR 200 4V FI  65450.0      Delhi      9238.0
# 9320                    TVS Apache 150cc  20000.0     Hissar     84916.0
# 9322           TVS Radeon 110cc Drum SBT  58000.0      Delhi      4020.0
#
#             owner   age  power brand
# 0     First Owner   3.0  110.0   TVS
# ...

# %%
tvs_brand['owner'].unique()
# Out:
# <StringArray>
# ['First Owner', 'Second Owner', 'Third Owner']
# Length: 3, dtype: str

# %%
tvs_first = tvs_brand[tvs_brand['owner']=='First Owner']

# %%
tvs_first
# Out:
#                                bike_name    price       city  kms_driven  \
# 0     TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 3                   TVS Apache RTR 180cc  65000.0  Bangalore     16329.0
# 52                  TVS Apache RTR 160cc  60000.0     Mumbai     30000.0
# 114           TVS Apache RTR 160 4V Disc  69900.0      Delhi      8700.0
# 130               TVS Phoenix Disc 125cc  21500.0    Barasat     10500.0
# ...                                  ...      ...        ...         ...
# 9247      TVS Apache RTR 160cc Rear Disc  70000.0  Ghaziabad      4116.0
# 9307                TVS Apache RTR 160cc  30000.0     Alibag     30000.0
# 9312            TVS Apache RTR 200 4V FI  65450.0      Delhi      9238.0
# 9320                    TVS Apache 150cc  20000.0     Hissar     84916.0
# 9322           TVS Radeon 110cc Drum SBT  58000.0      Delhi      4020.0
#
#             owner   age  power brand
# 0     First Owner   3.0  110.0   TVS
# ...

# %%
#duplicated value permannet drop,null drop,str --> num,unnecessary column drop

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
bajaj_brand = df[df['brand']=='Bajaj']

# %%
bajaj_brand
# Out:
#                      bike_name     price       city  kms_driven        owner  \
# 12          Bajaj Pulsar NS200   78000.0  Bangalore      9900.0  First Owner
# 13         Bajaj Discover 100M   29499.0      Delhi     20000.0  First Owner
# 14         Bajaj Discover 125M   29900.0      Delhi     20000.0  First Owner
# 15      Bajaj Pulsar NS200 ABS   90000.0  Bangalore     11574.0  First Owner
# 16      Bajaj Pulsar RS200 ABS  120000.0  Bangalore     23000.0  First Owner
# ...                        ...       ...        ...         ...          ...
# 9360        Bajaj Pulsar NS200   48000.0  Allahabad     41939.0  First Owner
# 9361       Bajaj Avenger 220cc   50000.0  Bangalore     29134.0  First Owner
# 9369       Bajaj Avenger 220cc   35000.0  Bangalore     60000.0  First Owner
# 9371     Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0  First Owner
# 9372  Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0  First Owner
#
#       age  power  brand
# ...

# %%
bajaj_under2 = bajaj_brand[bajaj_brand['age']<=2]

# %%
bajaj_under2
# Out:
#                              bike_name     price        city  kms_driven  \
# 43        Bajaj Avenger Street 220 ABS  110000.0   Bangalore      2550.0
# 95                  Bajaj Pulsar 150cc   60000.0        Pune      2000.0
# 141                 Bajaj Pulsar NS200  115000.0   Bangalore      5000.0
# 237              Bajaj Dominar 400 ABS  190000.0      Mandya      8780.0
# 283                 Bajaj Pulsar NS200  106000.0       Delhi      1175.0
# 340        Bajaj Pulsar 125cc Disc CBS   47000.0       Banki     14009.0
# 341           Bajaj Avenger Street 220   95000.0       Delhi     11000.0
# 395             Bajaj Pulsar RS200 ABS  130000.0      Mumbai     15000.0
# 510                 Bajaj Pulsar 150cc   66000.0       Delhi     15000.0
# 619           Bajaj V15 150cc POWER UP   35000.0      Mumbai     26000.0
# 853              Bajaj Dominar 400 ABS  195000.0      Mumbai      6000.0
# 889   Bajaj Pulsar 150cc Rear Disc ABS   85000.0    Balaghat      2500.0
# ...

# %%
bajaj_km20k = bajaj_under2[bajaj_under2['kms_driven']<=20000]

# %%
bajaj_km20k
# Out:
#                              bike_name     price        city  kms_driven  \
# 43        Bajaj Avenger Street 220 ABS  110000.0   Bangalore      2550.0
# 95                  Bajaj Pulsar 150cc   60000.0        Pune      2000.0
# 141                 Bajaj Pulsar NS200  115000.0   Bangalore      5000.0
# 237              Bajaj Dominar 400 ABS  190000.0      Mandya      8780.0
# 283                 Bajaj Pulsar NS200  106000.0       Delhi      1175.0
# 340        Bajaj Pulsar 125cc Disc CBS   47000.0       Banki     14009.0
# 341           Bajaj Avenger Street 220   95000.0       Delhi     11000.0
# 395             Bajaj Pulsar RS200 ABS  130000.0      Mumbai     15000.0
# 510                 Bajaj Pulsar 150cc   66000.0       Delhi     15000.0
# 853              Bajaj Dominar 400 ABS  195000.0      Mumbai      6000.0
# 889   Bajaj Pulsar 150cc Rear Disc ABS   85000.0    Balaghat      2500.0
# 1340         Bajaj Discover 125cc Disc   39000.0   Faridabad      9923.0
# ...

# %%
royalenfield = df[df['brand']=='Royal Enfield']

# %%
royalenfield
# Out:
#                                      bike_name     price       city  \
# 1                  Royal Enfield Classic 350cc  119900.0      Delhi
# 8            Royal Enfield Thunderbird X 350cc  145000.0  Bangalore
# 9     Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi
# 23          Royal Enfield Classic Chrome 500cc  121700.0     Kalyan
# 36                 Royal Enfield Classic 350cc   98800.0      Kochi
# ...                                        ...       ...        ...
# 9261               Royal Enfield Classic 500cc  146006.0   Guwahati
# 9319               Royal Enfield Classic 350cc  100000.0    Chennai
# 9337             Royal Enfield Himalayan 410cc  120000.0    Gurgaon
# 9338             Royal Enfield Himalayan 410cc  138000.0      Delhi
# 9344      Royal Enfield Bullet Twinspark 350cc   80000.0      Delhi
#
#       kms_driven         owner   age  power          brand
# 1        11000.0   First Owner   4.0  350.0  Royal Enfield
# ...

#
# 5918               Royal Enfield Thunderbird 350cc   45000.0  Bangalore
# 6282            Royal Enfield Bullet Electra 350cc   60000.0      Delhi
# 6685                   Royal Enfield‎ Bullet 350cc  120000.0  Bangalore
# 7860                   Royal Enfield‎ Bullet 350cc   65000.0    Gurgaon
# 8190            Royal Enfield Bullet Electra 350cc   85000.0      Bundi
# 8396                   Royal Enfield Classic 500cc  150000.0    Mathura
# ...

# %%
royalage = royal_kmdriven[royal_kmdriven['age']<=2]

# %%
royalage
# Out:
# Empty DataFrame
# Columns: [bike_name, price, city, kms_driven, owner, age, power, brand]
# Index: []

# %%
df[(df['brand']=='Royal Enfield') & (df['age']<=2) & (df['price']<=150000)]
# Out:
#                                              bike_name     price       city  \
# 194                        Royal Enfield Electra 350cc  145000.0  Bangalore
# 479                        Royal Enfield Classic 350cc  150000.0      Delhi
# 1006               Royal Enfield Thunderbird 350cc ABS  148000.0   Haldwani
# 1203     Royal Enfield Classic Gunmetal Grey 350cc ABS  150000.0  Bardhaman
# 1681             Royal Enfield Thunderbird X 350cc ABS  135000.0   Sibsagar
# 1716               Royal Enfield Thunderbird 350cc ABS  144700.0     Kharar
# 1749    Royal Enfield Bullet Twinspark Kickstart 350cc  145000.0      Delhi
# 2982      Royal Enfield Classic 350cc-Redditch Edition  137000.0  Sultanpur
# 5495                       Royal Enfield Classic 350cc  150000.0       Kota
# 5939    Royal Enfield Bullet Twinspark Kickstart 350cc  105000.0  Faridabad
# 6090  Royal Enfield Bullet Electra Twinspark 350CC ABS  127000.0     Mumbai
# ...

# %%
df.query("brand=='Royal Enfield' and age<=2 and kms_driven<50000")
# Out:
#                                          bike_name     price          city  \
# 38               Royal Enfield Thunderbird X 500cc  190500.0    Samastipur
# 81                 Royal Enfield Interceptor 650cc  260000.0   Navi Mumbai
# 139           Royal Enfield Himalayan 410cc Fi ABS  173300.0      Vadodara
# 194                    Royal Enfield Electra 350cc  145000.0     Bangalore
# 222           Royal Enfield Himalayan 410cc Fi ABS  177982.0  Hamirpur(hp)
# ...                                            ...       ...           ...
# 7294  Royal Enfield Classic 350cc-Redditch Edition  133500.0        Mumbai
# 7694        Royal Enfield Classic Chrome 500cc ABS  215000.0         Delhi
# 8139         Royal Enfield Thunderbird X 350cc ABS  169000.0     Bangalore
# 8192           Royal Enfield Thunderbird 350cc ABS  145000.0     Ghaziabad
# 8836         Royal Enfield Thunderbird X 350cc ABS  170200.0        Mumbai
#
#       kms_driven        owner  age  power          brand
# ...

# %%
df.drop(['bike_name','city'],axis=1,inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(18)

# %%
df.drop_duplicates()
# Out:
#          price  kms_driven        owner  age  power            brand
# 0      35000.0     17654.0  First Owner  3.0  110.0              TVS
# 1     119900.0     11000.0  First Owner  4.0  350.0    Royal Enfield
# 2     600000.0       110.0  First Owner  8.0  675.0          Triumph
# 3      65000.0     16329.0  First Owner  4.0  180.0              TVS
# 4      80000.0     10000.0  First Owner  3.0  150.0           Yamaha
# ...        ...         ...          ...  ...    ...              ...
# 9362   25000.0     48587.0  First Owner  8.0  150.0             Hero
# 9369   35000.0     60000.0  First Owner  9.0  220.0            Bajaj
# 9370  450000.0      3430.0  First Owner  4.0  750.0  Harley-Davidson
# 9371  139000.0     21300.0  First Owner  4.0  400.0            Bajaj
# 9372   80000.0      7127.0  First Owner  5.0  220.0            Bajaj
#
# [7306 rows x 6 columns]

# %%
df
# Out:
#          price  kms_driven        owner  age  power            brand
# 0      35000.0     17654.0  First Owner  3.0  110.0              TVS
# 1     119900.0     11000.0  First Owner  4.0  350.0    Royal Enfield
# 2     600000.0       110.0  First Owner  8.0  675.0          Triumph
# 3      65000.0     16329.0  First Owner  4.0  180.0              TVS
# 4      80000.0     10000.0  First Owner  3.0  150.0           Yamaha
# ...        ...         ...          ...  ...    ...              ...
# 9362   25000.0     48587.0  First Owner  8.0  150.0             Hero
# 9369   35000.0     60000.0  First Owner  9.0  220.0            Bajaj
# 9370  450000.0      3430.0  First Owner  4.0  750.0  Harley-Davidson
# 9371  139000.0     21300.0  First Owner  4.0  400.0            Bajaj
# 9372   80000.0      7127.0  First Owner  5.0  220.0            Bajaj
#
# [7324 rows x 6 columns]

# %%
x = df.drop('price',axis=1)
y = df[['price']]

# %%
x
# Out:
#       kms_driven        owner  age  power            brand
# 0        17654.0  First Owner  3.0  110.0              TVS
# 1        11000.0  First Owner  4.0  350.0    Royal Enfield
# 2          110.0  First Owner  8.0  675.0          Triumph
# 3        16329.0  First Owner  4.0  180.0              TVS
# 4        10000.0  First Owner  3.0  150.0           Yamaha
# ...          ...          ...  ...    ...              ...
# 9362     48587.0  First Owner  8.0  150.0             Hero
# 9369     60000.0  First Owner  9.0  220.0            Bajaj
# 9370      3430.0  First Owner  4.0  750.0  Harley-Davidson
# 9371     21300.0  First Owner  4.0  400.0            Bajaj
# 9372      7127.0  First Owner  5.0  220.0            Bajaj
#
# [7324 rows x 5 columns]

# %%
y
# Out:
#          price
# 0      35000.0
# 1     119900.0
# 2     600000.0
# 3      65000.0
# 4      80000.0
# ...        ...
# 9362   25000.0
# 9369   35000.0
# 9370  450000.0
# 9371  139000.0
# 9372   80000.0
#
# [7324 rows x 1 columns]

# %%
df.to_csv("clean_bike.csv")
